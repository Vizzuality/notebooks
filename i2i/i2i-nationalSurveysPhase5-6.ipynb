# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#New-indicators" data-toc-modified-id="New-indicators-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>New indicators</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Ensure-that-the-current-indicators-and-filters-has-the-same-formats-as-expected." data-toc-modified-id="Ensure-that-the-current-indicators-and-filters-has-the-same-formats-as-expected.-1.0.1"><span class="toc-item-num">1.0.1&nbsp;&nbsp;</span>Ensure that the current indicators and filters has the same formats as expected.</a></span></li></ul></li><li><span><a href="#Lets-explore-the-new-ones" data-toc-modified-id="Lets-explore-the-new-ones-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Lets explore the new ones</a></span><ul class="toc-item"><li><span><a href="#Propossed-structure-for-new-indicators" data-toc-modified-id="Propossed-structure-for-new-indicators-1.1.1"><span class="toc-item-num">1.1.1&nbsp;&nbsp;</span>Propossed structure for new indicators</a></span></li></ul></li></ul></li><li><span><a href="#SMME-indicators" data-toc-modified-id="SMME-indicators-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>SMME indicators</a></span><ul class="toc-item"><li><span><a href="#Propossed-structure-for-new-indicators" data-toc-modified-id="Propossed-structure-for-new-indicators-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Propossed structure for new indicators</a></span></li></ul></li></ul></div>

# %%
import pandas as pd
import plotly
import requests
from requests.auth import HTTPBasicAuth
import getpass
from pivottablejs import pivot_ui
import cufflinks as cf
import plotly.offline
import json
cf.go_offline()
cf.set_config_file(offline=False, world_readable=True)
baseUrl = '/home/jovyan/work/datasets'
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# Requirements:
# - New indicators:
#     - [DATA](https://basecamp.com/1756858/projects/16224488/messages/87398455)
#         USD per day
#         Poverty line
#         Electricity access
#         Cooking energy
#         Salary‎ formally paid
#         Transactions (we will have to work with overalls here)
#         Mobile money (we will have to work with overalls here)
#         Asset ladder (Lifestyle - 3 categories.)
#         Water
#         Hunger symptom
#         Health symptom
#         Education symptom
#         Toilet type
#
# - New Section: **SMME (Small, Medium and Micro-sized Enterprises)** .
#     - [DATA](https://basecamp.com/1756858/projects/16224488/messages/87399105)
#
#         This will be a new interface for businesses, the current interface is for consumers only.
#
#         The new indicators for this survey are;
#
#         Employees (total)
#         Jurisdiction
#         Urb/rur
#         Gender of owner – Total will be the number of owners
#         Age of owner
#         Business size
#         Business development measure
#         Business age -  this will determine the age if the business
#         Registration/ Licenced – a few categories
#         Financial records
#         Sector – a few categories
#         Ownership structure – a few categories
#         Motives for starting a business
#         Skills – a few categories
#         Business coaching
#         Capital used to start
#         Infrastructure – a few categories
#         Financial inclusion (Banked, Other formal, Informal, Credit, Savings, Insurance, Transactions, MM account) – a few categories
#         Barriers from starting business– a few categories
#         Biggest obstacle to growing business
#
#
# *Actions:*
# * New indicators;
#     - are they on the same format that the rest of the data?
#     - Check feaseability of the new indicators to be uploaded to the api
#
# * New Section;
#     - are they on the same format that the rest of the data?
#     - Possible visualizations

# %% [markdown]
# # New indicators

# %%
"""
This object will be use as the reference one. not all datasets will have the same columns. this object will be created once and will grow after each run of the algorithm.
allways trim and substitute empty values by null ones
{
colName:{ acceptedN: [set of similars built with every new one] each column will have its own why,
          acceptedV:{ valA: [set of similars built with every new one] each column will have its own why}
          toGetrid: "years"
          cat: True
          json: {
            "indicatorId": "geographic_area",
            "childIndicatorId": null,
            "answerId": null
        }
    }
}
"""
password = getpass.getpass(prompt='Password: ')
def uploadFunction(info):
    """
    Recive info as an dict with:
    {
    iso:
    year:
    fileUrl:
    jsonUrl:    
    }
    """
    url = 'https://staging.i2ifacility.org/api/v1/country/{iso}/{year}/dataset'.format(iso=info["iso"],year=info["year"])
    files1 = {'json': open(info["jsonUrl"], 'rb'), 'csv': open(info["fileUrl"], 'rb')}
    r = requests.post(url,auth=HTTPBasicAuth('vizzuality', password), files=files1)
    return r.text
# Out:
# Password: ········

# %%
NewIndicators = pd.read_excel(f'{baseUrl}/i2i/newDatav5-6/FS Myanmar 2018 Final Data Set Shortened 13Sep19 final.xlsx')
NewIndicators.head(5)
# Out:
#    ID    Weight_Ind Jurisdiction  Gender Urb_rur Banked  \
# 0   1   4070.864692       Yangon  Female   Rural    NaN
# 1   2   2580.878114       Yangon  Female   Rural    NaN
# 2   3  17116.483380       Yangon    Male   Rural    NaN
# 3   4   3627.829699       Yangon  Female   Rural    NaN
# 4   5   8051.798947       Yangon    Male   Rural    NaN
#
#               Other_Formal  Informal                      FAS Credit_B  ...  \
# 0                      NaN  Informal            Informal only      NaN  ...
# 1                      NaN  Informal            Informal only      NaN  ...
# 2  Other formal (non-bank)  Informal  Other formal (non-bank)      NaN  ...
# 3                      NaN       NaN                 Excluded      NaN  ...
# 4  Other formal (non-bank)  Informal  Other formal (non-bank)      NaN  ...
#
#                Basic_assets              Asset_ladder  \
# 0  People with basic assets      Middle class segment
# 1  People with basic assets      Middle class segment
# ...

# %%
NewIndicators.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5500 entries, 0 to 5499
# Data columns (total 51 columns):
# ID                       5500 non-null int64
# Weight_Ind               5500 non-null float64
# Jurisdiction             5500 non-null object
# Gender                   5500 non-null object
# Urb_rur                  5500 non-null object
# Banked                   1414 non-null object
# Other_Formal             1889 non-null object
# Informal                 2788 non-null object
# FAS                      5500 non-null object
# Credit_B                 810 non-null object
# Credit_F                 987 non-null object
# Credit_Inf               1310 non-null object
# Credit_FF                742 non-null object
# Credit_strand            5500 non-null object
# Remittances_B            310 non-null object
# Remittances_F            570 non-null object
# Remittances_Inf          112 non-null object
# Remittances_FF           172 non-null object
# ...

# %%
pivot_ui(NewIndicators)
# Out:
#         <iframe
#             width="100%"
#             height="500"
#             src="pivottablejs.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ### Ensure that the current indicators and filters has the same formats as expected.

# %%
dfvaris=[[NewIndicators,NewIndicators.columns.values,'mmr2018']]
for i, data in enumerate(dfvaris):
    poblacion = sum(data[0]['Weight_Ind'])
    mujeres = data[0][data[0]['Gender'] == 'Female']
    total_mujeres = sum(mujeres['Weight_Ind'])
    hombres = data[0][data[0]['Gender'] == 'Male']
    total_hombres = sum(hombres['Weight_Ind'])
    print('_________________ ',data[2])
    print('Mujeres: ',total_mujeres)
    print('Hombres: ',total_hombres)
    print('Total: ', poblacion)
# Out:
# _________________  mmr2018
# Mujeres:  17404908.815523382
# Hombres:  16918254.54906298
# Total:  34323163.36458628

# %%
for column in NewIndicators.columns:
    if column not in ['ID','Formally_employed','Poverty_line', 'Comfortable_assets', 'Average_assets', 'Basic_assets',
       'Asset_ladder', 'USD_per_day', 'Electricity_access', 'Cooking_energy',
       'Education_symptom', 'Hunger_symptom', 'Health_symptom', 'Toilet_type',
       'Water_source_type']:
        print(NewIndicators.groupby(column)[column].count())
        print('_________________________________________________________')
# Out:
# Weight_Ind
# 141.686340      1
# 150.315910      1
# 182.883605      1
# 194.252319      1
# 210.519349      1
#                ..
# 24059.076350    1
# 24421.467530    1
# 24546.352050    1
# 25871.581470    1
# 26958.502680    1
# Name: Weight_Ind, Length: 4240, dtype: int64
# _________________________________________________________
# Jurisdiction
# Ayeyawady      620
# Bago           500
# Chin           170
# Kachin         170
# Kayah          170
# Kayin          170
# Magway         410
# Mandalay       650
# Mon            200
# Nay Pyi Taw    170
# Rakhine        210
# Sagaing        540
# Shan           550
# Tanintharyi    170
# Yangon         800
# Name: Jurisdiction, dtype: int64
# _________________________________________________________
# Gender
# Female    3441
# Male      2059
# Name: Gender, dtype: int64
# _________________________________________________________
# Urb_rur
# Rural    3800
# Urban    1700
# Name: Urb_rur, dtype: int64
# ...

# %% [markdown]
# ## Lets explore the new ones

# %%
newCols = NewIndicators[['Formally_employed','Poverty_line', 'Comfortable_assets', 'Average_assets', 'Basic_assets',
       'Asset_ladder', 'USD_per_day', 'Electricity_access', 'Cooking_energy',
       'Education_symptom', 'Hunger_symptom', 'Health_symptom', 'Toilet_type',
       'Water_source_type']]
newCols.head(5)
# Out:
#            Formally_employed                        Poverty_line  \
# 0  Formally employed (SDG 8)  Above poverty line ($1.90 per day)
# 1                        NaN  Below poverty line ($1.90 per day)
# 2                        NaN  Below poverty line ($1.90 per day)
# 3                        NaN  Below poverty line ($1.90 per day)
# 4                        NaN  Above poverty line ($1.90 per day)
#
#   Comfortable_assets        Average_assets              Basic_assets  \
# 0                NaN  Middle class segment  People with basic assets
# 1                NaN  Middle class segment  People with basic assets
# 2                NaN  Middle class segment  People with basic assets
# 3                NaN                   NaN  People with basic assets
# 4                NaN  Middle class segment  People with basic assets
#
#                Asset_ladder              USD_per_day  \
# 0      Middle class segment    $1.91 - $6.65 per day
# ...

# %%
for colum in newCols.columns:
    print(newCols.groupby(colum)[colum].count())
    print('_________________________________________________________')
# Out:
# Formally_employed
# Formally employed (SDG 8)    370
# Name: Formally_employed, dtype: int64
# _________________________________________________________
# Poverty_line
# Above poverty line ($1.90 per day)    2672
# Below poverty line ($1.90 per day)    1993
# Name: Poverty_line, dtype: int64
# _________________________________________________________
# Comfortable_assets
# People living comfortably/affluent    1341
# Name: Comfortable_assets, dtype: int64
# _________________________________________________________
# Average_assets
# Middle class segment    4883
# Name: Average_assets, dtype: int64
# _________________________________________________________
# Basic_assets
# People with basic assets    5064
# Name: Basic_assets, dtype: int64
# _________________________________________________________
# Asset_ladder
# Middle class segment                  3560
# None                                   150
# People living comfortably/affluent    1341
# ...

# %% [markdown]
# ### Propossed structure for new indicators
# new common indicators:
# * Water_source_type
# * Toilet_type
# * Cooking_energy
# * Electricity_access
#
# new ind families:
# * asset:
#     - Comfortable_assets
#     - Basic_assets
#     - Average_assets
#
#     - Asset_ladder
# * SDGs:
#     - Health_symptom
#     - Hunger_symptom
#     - Education_symptom
#     - Formally_employed
#
# * Poverty:
#     - Poverty_line
#     - USD_per_day

# %%
url = 'https://staging.i2ifacility.org/api/v1/indicator'
r = requests.get(url)
r.json()
# Out:
# ['geographic_area',
#  'gender',
#  'age',
#  'access_to_resources',
#  'dwelling_type',
#  'i2i_Marital_Status',
#  'i2i_Education',
#  'i2i_Income_Sources',
#  'fas_strand',
#  'savings_strand',
#  'remittances_strand',
#  'insurance_strand',
#  'credit_strand',
#  'total_fas_strand',
#  'total_saving_strand',
#  'total_remittances_strand',
#  'total_insurance_strand',
#  'total_credit_strand',
#  'toilet_type',
#  'cooking_energy_type',
#  'electricity_access_type',
#  'usd_per_day',
#  'poverty_line',
#  'mobile_money',
#  'asset_strand',
#  'total_asset_strand',
#  'sdgs_strand']

# %%
NewIndicators.columns
# Out:
# Index(['ID', 'Weight_Ind', 'Jurisdiction', 'Gender', 'Urb_rur', 'Banked',
#        'Other_Formal', 'Informal', 'FAS', 'Credit_B', 'Credit_F', 'Credit_Inf',
#        'Credit_FF', 'Credit_strand', 'Remittances_B', 'Remittances_F',
#        'Remittances_Inf', 'Remittances_FF', 'Remittances_strand', 'Savings_B',
#        'Savings_F', 'Savings_Inf', 'Savings_AH', 'Savings_strand',
#        'Transactions_B', 'Transactions_MM', 'Transactions_F',
#        'Transactions_strand', 'Insurance_B', 'Insurance_F', 'Insurance_Inf',
#        'Insurance_strand', 'Mobile_money ', 'i2i_Sources_of_income',
#        'i2i_Education', 'i2i_Marital_status', 'i2i_Age', 'Formally_employed',
#        'Poverty_line', 'Comfortable_assets', 'Average_assets', 'Basic_assets',
#        'Asset_ladder', 'USD_per_day', 'Electricity_access', 'Cooking_energy',
#        'Education_symptom', 'Hunger_symptom', 'Health_symptom', 'Toilet_type',
#        'Water_source_type'],
#       dtype='object')

# %%
"""
adding new indicators will require an update of this table https://github.com/Vizzuality/i2i-api/edit/develop/app/src/data/indicators.json
"""

useJson =json.loads("""{
    "weightColumn": "Weight_Ind",
    "indicators":{
        "Urb_rur": {
            "indicatorId": "geographic_area",
            "childIndicatorId": null,
            "answerId": null
        },
        "Jurisdiction":{
            "indicatorId": "jurisdiction",
            "childIndicatorId": null,
            "answerId": null
        },
        "Gender": {
            "indicatorId": "gender",
            "childIndicatorId": null,
            "answerId": null
        },
        "i2i_Age": {
            "indicatorId": "age",
            "childIndicatorId": null,
            "answerId": null
        },
        "i2i_Marital_Status":{
            "indicatorId": "i2i_Marital_Status",
            "childIndicatorId": null,
            "answerId": null
        },
        "i2i_Education": {
            "indicatorId": "i2i_Education",
            "childIndicatorId": null,
            "answerId": null
        },
        "i2i_Sources_of_income": {
            "indicatorId": "i2i_Income_Sources",
            "childIndicatorId": null,
            "answerId": null
        },
        "Water_source_type":{
            "indicatorId": "water_source_type",
            "childIndicatorId": null,
            "answerId": null
        },
        "Toilet_type":{
            "indicatorId": "toilet_type",
            "childIndicatorId": null,
            "answerId": null
        },
        "Cooking_energy":{
            "indicatorId": "cooking_energy_type",
            "childIndicatorId": null,
            "answerId": null
        },
        "Electricity_access":{
            "indicatorId": "electricity_access_type",
            "childIndicatorId": null,
            "answerId": null
        },
        "USD_per_day":{
            "indicatorId": "usd_per_day",
            "childIndicatorId": null,
            "answerId": null
        },
        "Poverty_line":{
            "indicatorId": "poverty_line",
            "childIndicatorId": null,
            "answerId": null
        },

        "Banked": {
            "indicatorId": "fas_strand",
            "childIndicatorId": null,
            "answerId": 1
        },
        "Other_formal": {
            "indicatorId": "fas_strand",
            "childIndicatorId": null,
            "answerId": 2
        },
        "Informal": {
            "indicatorId": "fas_strand",
            "childIndicatorId": null,
            "answerId": 3
        },
        "fas_access": {
            "indicatorId": "fas_strand",
            "childIndicatorId": null,
            "answerId": 4
        },
        "Savings_B":{
            "indicatorId": "savings_strand",
            "childIndicatorId": null,
            "answerId": 1
        },
        "Savings_F":{
            "indicatorId": "savings_strand",
            "childIndicatorId": null,
            "answerId": 2
        },
        "Savings_Inf":{
            "indicatorId": "savings_strand",
            "childIndicatorId": null,
            "answerId": 3
        },
        "Savings_AH":{
            "indicatorId": "savings_strand",
            "childIndicatorId": null,
            "answerId": 4
        },
        "savings_access":{
            "indicatorId": "savings_strand",
            "childIndicatorId": null,
            "answerId": 5
        },
        "Remittances_B":{
            "indicatorId": "remittances_strand",
            "childIndicatorId": null,
            "answerId": 1
        },
        "Remittances_F":{
            "indicatorId": "remittances_strand",
            "childIndicatorId": null,
            "answerId": 2
        },
        "Remittances_Inf":{
            "indicatorId": "remittances_strand",
            "childIndicatorId": null,
            "answerId": 3
        },
        "Remittances_FF":{
            "indicatorId": "remittances_strand",
            "childIndicatorId": null,
            "answerId": 4
        },
        "Remittances_access":{
            "indicatorId": "remittances_strand",
            "childIndicatorId": null,
            "answerId": 5
        },
        "Insurance_F":{
            "indicatorId": "insurance_strand",
            "childIndicatorId": null,
            "answerId": 1
        },
        "Insurance_Inf":{
            "indicatorId": "insurance_strand",
            "childIndicatorId": null,
            "answerId": 2
        },
        "Insurance_B":{
            "indicatorId": "insurance_strand",
            "childIndicatorId": null,
            "answerId": 3
        },
        "insurance_access":{
            "indicatorId": "insurance_strand",
            "childIndicatorId": null,
            "answerId": 4
        },
        "Credit_B":{
            "indicatorId": "credit_strand",
            "childIndicatorId": null,
            "answerId": 1
        },
        "Credit_F":{
            "indicatorId": "credit_strand",
            "childIndicatorId": null,
            "answerId": 2
        },
        "Credit_Inf":{
            "indicatorId": "credit_strand",
            "childIndicatorId": null,
            "answerId": 3
        },
        "Credit_FF":{
            "indicatorId": "credit_strand",
            "childIndicatorId": null,
            "answerId": 4
        },
        "credit_access":{
            "indicatorId": "credit_strand",
            "childIndicatorId": null,
            "answerId": 5
        },
        "Weight_Ind":{
            "indicatorId": "weight_ind",
            "childIndicatorId": null,
            "answerId": null
        },
        "FAS":{
            "indicatorId": "total_fas_strand",
            "childIndicatorId": null,
            "answerId": 1
        },
        "Savings_Strand":{
            "indicatorId": "total_saving_strand",
            "childIndicatorId": null,
            "answerId": 2
        },
        "Remittances_Strand":{
            "indicatorId": "total_remittances_strand",
            "childIndicatorId": null,
            "answerId": 3
        },
        "Insurance_Strand":{
            "indicatorId": "total_insurance_strand",
            "childIndicatorId": null,
            "answerId": 4
        },
        "Mobile_money ":{
            "indicatorId": "mobile_money",
            "childIndicatorId": null,
            "answerId": null
        },
        "Credit_Strand":{
            "indicatorId": "total_credit_strand",
            "childIndicatorId": null,
            "answerId": 5
        },
        "Basic_assets":{
            "indicatorId": "asset_strand",
            "childIndicatorId": null,
            "answerId": 1
        },
        "Average_assets":{
            "indicatorId": "asset_strand",
            "childIndicatorId": null,
            "answerId": 2
        },
        "Comfortable_assets":{
            "indicatorId": "asset_strand",
            "childIndicatorId": null,
            "answerId": 3
        },
        "Asset_ladder":{
            "indicatorId": "total_asset_strand",
            "childIndicatorId": null,
            "answerId": 6
        },
        "Health_symptom":{
            "indicatorId": "sdgs_strand",
            "childIndicatorId": null,
            "answerId": 1
        },
        "Hunger_symptom":{
            "indicatorId": "sdgs_strand",
            "childIndicatorId": null,
            "answerId": 2
        },
        "Education_symptom":{
            "indicatorId": "sdgs_strand",
            "childIndicatorId": null,
            "answerId": 3
        },
        "Formally_employed":{
            "indicatorId": "sdgs_strand",
            "childIndicatorId": null,
            "answerId": 4
        }
    }
}""")
with open(f'{baseUrl}/i2i/newDatav5-6/FS Myanmar 2018 Final Data Set Shortened 13Sep19 final.json', 'w') as outfile:
    json.dump(useJson, outfile, sort_keys=True, indent=4)
NewIndicators.to_csv(f'{baseUrl}/i2i/newDatav5-6/FS Myanmar 2018 Final Data Set Shortened 13Sep19 final.csv')

# %%
info={
    'iso':'MMR',
    'year':2018,
    'fileUrl':f'{baseUrl}/i2i/newDatav5-6/FS Myanmar 2018 Final Data Set Shortened 13Sep19 final.csv',
    'jsonUrl':f'{baseUrl}/i2i/newDatav5-6/FS Myanmar 2018 Final Data Set Shortened 13Sep19 final.json' 
    }
uploadFunction(info)
# Out:
# '{"ok":1}'

# %%
url = 'https://staging.i2ifacility.org/api/v1/indicator'
r = requests.get(url)
r.json()
# Out:
# ['geographic_area',
#  'gender',
#  'age',
#  'access_to_resources',
#  'dwelling_type',
#  'i2i_Marital_Status',
#  'i2i_Education',
#  'i2i_Income_Sources',
#  'fas_strand',
#  'savings_strand',
#  'remittances_strand',
#  'insurance_strand',
#  'credit_strand',
#  'total_fas_strand',
#  'total_saving_strand',
#  'total_remittances_strand',
#  'total_insurance_strand',
#  'total_credit_strand']

# %% [markdown]
# # SMME indicators

# %%
SMMEIndicators = pd.read_excel(f'{baseUrl}/i2i/newDatav5-6/FS_MSME Swaziland_Shortened_Version_13Sept19 final .xlsx')
SMMEIndicators.head(5)
# Out:
#          ID  Weights_Ind_Business_Owner Jurisdiction Urb_rur Owner_gender  \
# 0  39342448                   23.494456       Hhohho   Rural       Female
# 1  39342449                   23.494456       Hhohho   Rural       Female
# 2  39346339                   23.494456       Hhohho   Rural       Female
# 3  39346613                   23.494456       Hhohho   Rural         Male
# 4  39372440                   23.494456       Hhohho   Rural       Female
#
#   Age_of_owner                           Business_size  \
# 0    61+ years  Independent entreprenuer (0 employees)
# 1  46-60 years          Micro Business (1-3 employees)
# 2  46-60 years  Independent entreprenuer (0 employees)
# 3  35-45 years  Independent entreprenuer (0 employees)
# 4  46-60 years  Independent entreprenuer (0 employees)
#
#                   Business_age Infrastructure_electricity  \
# 0  Mature (More than 10 years)             No electricity
# 1  Mature (More than 10 years)             No electricity
# ...

# %%
pivot_ui(SMMEIndicators)
# Out:
#         <iframe
#             width="100%"
#             height="500"
#             src="pivottablejs.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
SMMEIndicators.columns
# Out:
# Index(['ID', 'Weights_Ind_Business_Owner', 'Jurisdiction', 'Urb_rur',
#        'Owner_gender', 'Age_of_owner', 'Business_size', 'Business_age',
#        'Infrastructure_electricity', 'Infrastructure_Telephone',
#        'Infrastructure_Cellphone', 'Infrastructure_Internet_access',
#        'Motives_of_starting_business1', 'Motives_of_starting_business2',
#        'Motives_of_starting_business3', 'Motives_of_starting_business4',
#        'Motives_of_starting_business5', 'Barriers_from_starting_business1',
#        'Barriers_from_starting_business2', 'Barriers_from_starting_business3',
#        'Barriers_from_starting_business4', 'Barriers_from_starting_business5',
#        'Sources_of_capital1', 'Sources_of_capital2', 'Sources_of_capital3',
#        'Sources_of_capital4', 'Sources_of_capital5', 'Business_Sector',
#        'Licensed_registered', 'Business_coaching',
#        'Business_Development_Measure', 'No_of_employees',
#        'Top5_motives_starting_business',
# ...

# %% [markdown]
# ## Propossed structure for new indicators
#
# **Common indicators:**
#
# * Urb_rur
# * Owner_gender
# * Age_of_owner
#
# * Business_size
# * Business_age
# * Business_Sector
# * Licensed_registered
# * Business_coaching
# * Business_Development_Measure
# * No_of_employees
# * Financial_records
# **Indicator families:**
#
# * Infrastructure:
#     * Infrastructure_electricity
#     * Infrastructure_Telephone
#     * Infrastructure_Cellphone
#     * Infrastructure_Internet_access
#
# * Motives:
#     * Motives_of_starting_business1
#     * Motives_of_starting_business2
#     * Motives_of_starting_business3
#     * Motives_of_starting_business4
#     * Motives_of_starting_business5
#
# * Barriers:
#     * Barriers_from_starting_business1
#     * Barriers_from_starting_business2
#     * Barriers_from_starting_business3
#     * Barriers_from_starting_business4
#     * Barriers_from_starting_business5
#
# * Sources of capital:
#     * Sources_of_capital1
#     * Sources_of_capital2
#     * Sources_of_capital3
#     * Sources_of_capital4
#     * Sources_of_capital5
#
# * Top5_sources_of_capital
# * Top5_source_of_skills
# * Top5_motives_starting_business
#
# * Top5_barriers_from_starting_business
# * Biggest_obstacle_to_growing_business
#
#
# * fas_strand
#     * Banked
#     * Other_formal
#     * Informal
# * credit_strand
#     * Credit_B
#     * Credit_F
#     * Credit_Inf
#     * Credit_FF
# * savings_strand
#     * Saving_B
#     * Savings_F
#     * Saving_Inf
#     * Savings_FF
# * insurance_strand
#     * Insurance_F
# * transaction_strand
#     * Transactions_B
#     * Transactions_F
# * mobile_money
#     * MM_account

# %%
SMMEIndicatorsTest = SMMEIndicators.copy()
replace_map_comp = {}
for column in SMMEIndicatorsTest.columns:
    if column not in ('ID', 'Weights_Ind_Business_Owner'):
        
        labels =SMMEIndicatorsTest[column].astype('category').cat.categories.tolist()
        replace_map_comp.update( {column : {k: v for k,v in zip(labels,list(range(1,len(labels)+1)))}})

SMMEIndicatorsTest.replace(replace_map_comp, inplace=True)
print(replace_map_comp)
SMMEIndicatorsTest.head()
# Out:
# {'Jurisdiction': {'Hhohho': 1, 'Lubombo': 2, 'Manzini': 3, 'Shiselweni': 4}, 'Urb_rur': {'Rural': 1, 'Urban': 2}, 'Owner_gender': {'Female': 1, 'Male': 2}, 'Age_of_owner': {'18-24 years': 1, '25-34 years': 2, '35-45 years': 3, '46-60 years': 4, '61+ years': 5}, 'Business_size': {'Independent entreprenuer (0 employees)': 1, 'Medium Business (11 - 50 employees)': 2, 'Micro Business (1-3 employees)': 3, 'Small Business (4 - 10 employees)': 4}, 'Business_age': {'Established (6-10 years)': 1, 'Growth (3-5 years)': 2, 'Mature (More than 10 years)': 3, 'Start up (0-2 years)': 4}, 'Infrastructure_electricity': {'Have electricity': 1, 'No electricity': 2}, 'Infrastructure_Telephone': {'Have telephone/landline': 1, 'No telephone/landline': 2}, 'Infrastructure_Cellphone': {'Have cell phone': 1, 'No cellphone': 2}, 'Infrastructure_Internet_access': {'Have internet access': 1, 'No internet access': 2}, 'Motives_of_starting_business1': {'Saw an opportunity': 1}, 'Motives_of_starting_business2': {'
# ...

# %%
SMMEIndicatorsTest.corr().iplot(kind='heatmap', colorscale='Blues', title='Correlation matrix')
# Out:
# <div>
#
#
#             <div id="666f3f24-9567-4c58-95c2-3bee8d3d8f93" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("666f3f24-9567-4c58-95c2-3bee8d3d8f93")) {
#                     Plotly.newPlot(
#                         '666f3f24-9567-4c58-95c2-3bee8d3d8f93',
# ...

# %%
for colum in SMMEIndicators.columns:
    print(SMMEIndicators.groupby(colum)[colum].count())
    print('_________________________________________________________')
# Out:
# ID
# 39342448    1
# 39342449    1
# 39346339    1
# 39346613    1
# 39372440    1
#            ..
# 44332608    1
# 44334145    1
# 44335665    1
# 44338265    1
# 44449313    1
# Name: ID, Length: 3024, dtype: int64
# _________________________________________________________
# Weights_Ind_Business_Owner
# 2.106303      4
# 2.180404      2
# 2.307724      1
# 2.531179      4
# 3.395412      5
#              ..
# 190.598776    1
# 211.721807    1
# 247.715312    1
# 248.420253    1
# 289.660945    1
# Name: Weights_Ind_Business_Owner, Length: 860, dtype: int64
# _________________________________________________________
# Jurisdiction
# Hhohho        943
# Lubombo       540
# Manzini       966
# Shiselweni    575
# Name: Jurisdiction, dtype: int64
# _________________________________________________________
# Urb_rur
# Rural    2043
# Urban     981
# Name: Urb_rur, dtype: int64
# _________________________________________________________
# Owner_gender
# Female    2024
# Male      1000
# ...
